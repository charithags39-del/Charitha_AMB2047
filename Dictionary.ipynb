# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("Dictionary->",CGPA)
print("Total elments->",len(CGPA))
print("Type of object->",type(CGPA))
# Out:
# Dictionary-> {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# Total elments-> 5
# Type of object-> <class 'dict'>

# %%
print("\nCGPA of 1:",CGPA[1])
print("CGPA of 2:",CGPA[2])
print("CGPA of 4:",CGPA[4])
print("CGPA of 7:",CGPA[7])
print("CGPA of 3:",CGPA[3])
# Out:
# CGPA of 1: 8.9
# CGPA of 2: 5.6
# CGPA of 4: 6.7
# CGPA of 7: 9.1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3108706168.py in <cell line: 0>()
#       3 print("CGPA of 4:",CGPA[4])
#       4 print("CGPA of 7:",CGPA[7])
# ----> 5 print("CGPA of 3:",CGPA[3])
#
# KeyError: 3

# %%
for k in CGPA:
  print("CGPA of",k,"-->",CGPA[k])
# Out:
# CGPA of 1 --> 8.9
# CGPA of 2 --> 5.6
# CGPA of 4 --> 6.7
# CGPA of 7 --> 9.1
# CGPA of 8 --> 5.3

# %%
print("keys",CGPA.keys())
print("values",CGPA.values())
# Out:
# keys dict_keys([1, 2, 4, 7, 8])
# values dict_values([8.9, 5.6, 6.7, 9.1, 5.3])

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
CGPA[3]=8.6
print("After adding(3)",CGPA)
CGPA[9]=7.6
print("After adding(9)",CGPA)
CGPA[10]=8.6
print("After adding(10)",CGPA)
CGPA[10]=9.6
print("After adding(10)",CGPA)
# Out:
# After adding(3) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6}
# After adding(9) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6, 9: 7.6}
# After adding(10) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6, 9: 7.6, 10: 8.6}
# After adding(10) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6, 9: 7.6, 10: 9.6}

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
CGPA[10]=8.6
print("After adding(10)",CGPA)
# Out:
# After adding(10) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 10: 8.6}

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
CGPA[10]=9.6
print("After adding(10)",CGPA)
# Out:
# After adding(10) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 10: 9.6}

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
del CGPA[8]
print("After deleting(8)",CGPA)
del CGPA[1]
print("After deleting(1)",CGPA)
del CGPA[1]
print("After deleting(1)",CGPA)
# Out:
# After deleting(8) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1}
# After deleting(1) {2: 5.6, 4: 6.7, 7: 9.1}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3513680769.py in <cell line: 0>()
#       4 del CGPA[1]
#       5 print("After deleting(1)",CGPA)
# ----> 6 del CGPA[1]
#       7 print("After deleting(1)",CGPA)
#
# KeyError: 1

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
CGPA.clear()
print("After clearing",CGPA )
# Out:
# After clearing {}

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
s=0
for i in CGPA:
  s=s+CGPA[i]

print("Sum of CGPA",s)
print("Average of CGPA",s/len(CGPA))
print("Average of CGPA",s//len(CGPA))
# Out:
# Sum of CGPA 35.599999999999994
# Average of CGPA 7.119999999999999
# Average of CGPA 7.0

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("Sum",sum(CGPA.values()))
print("Average",sum(CGPA.values())/len(CGPA))
print("Average",sum(CGPA.values())//len(CGPA))
# Out:
# Sum 35.6
# Average 7.12
# Average 7.0

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("maximum",min(CGPA.values()))
print("minimum",max(CGPA.values()))
# Out:
# maximum 5.3
# minimum 9.1

# %%
print("Key with lowest value:", min(CGPA, key=CGPA.get))
# Out:
# Key with lowest value: 8

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print(CGPA.keys())
print(CGPA.values())
print(CGPA.items())
# Out:
# dict_keys([1, 2, 4, 7, 8])
# dict_values([8.9, 5.6, 6.7, 9.1, 5.3])
# dict_items([(1, 8.9), (2, 5.6), (4, 6.7), (7, 9.1), (8, 5.3)])

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print(list(CGPA.keys()))
print(list(CGPA.values()))
print(list(CGPA.items()))
# Out:
# [1, 2, 4, 7, 8]
# [8.9, 5.6, 6.7, 9.1, 5.3]
# [(1, 8.9), (2, 5.6), (4, 6.7), (7, 9.1), (8, 5.3)]

# %%
keylist=list(CGPA.keys())
valuelist=list(CGPA.values())
minimal=min(CGPA.values())
print("Value=",minimal,"Key->",keylist[valuelist.index(minimal)])
# Out:
# Value= 5.3 Key-> 8

# %%
keylist=list(CGPA.keys())
valuelist=list(CGPA.values())
maximal=max(CGPA.values())
print("Value=",maximal,"Key",keylist[valuelist.index(maximal)])
# Out:
# Value= 9.1 Key 7

# %%
print("Key with lowest value:", min(CGPA, key=CGPA.get))
# Out:
# Key with lowest value: 8

# %%
print("Key with highest value:", max(CGPA, key=CGPA.get))
# Out:
# Key with highest value: 7

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("Dictionary->",CGPA)
print("Is Key 2 present->",2 in CGPA.keys())
print("Is Key 9 present->",9 in CGPA.keys())
print("Is Key 2 present->",2 not in CGPA.keys())
# Out:
# Dictionary-> {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# Is Key 2 present-> True
# Is Key 9 present-> False
# Is Key 2 present-> False

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("Dictionary->",CGPA)
print("Is Value 8.9 Present->",8.9 in CGPA.values())
print("Is Value 5.6 Present->",5.6 in CGPA.values())
# Out:
# Dictionary-> {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# Is Value 8.9 Present-> True
# Is Value 5.6 Present-> True

# %%
CGPA={1:8.9,2:5.6,4:9.7}
CGPA1={4:6.7,7:9.1,8:5.3}
CGPA1.update(CGPA)
print("After Updating->",CGPA1)
# Out:
# After Updating-> {4: 9.7, 7: 9.1, 8: 5.3, 1: 8.9, 2: 5.6}

# %%
cars={"Brand":"Ford","Model":"Mustang","Year":1964}
print("cars-->",cars)
# Out:
# cars--> {'Brand': 'Ford', 'Model': 'Mustang', 'Year': 1964}

# %%
print("Brand-->",cars["Brand"])
print("Model-->",cars["Model"])
print("Year-->",cars["Year"])
# Out:
# Brand--> Ford
# Model--> Mustang
# Year--> 1964

# %%
cars["Colour"]="Red"
print("cars-->",cars)
# Out:
# cars--> {'Brand': 'Ford', 'Model': 'Mustang', 'Year': 1964, 'Colour': 'Red'}

# %%
print(cars.keys())
print(cars.values())
print(cars.items())
# Out:
# dict_keys(['Brand', 'Model', 'Year', 'Colour'])
# dict_values(['Ford', 'Mustang', 1964, 'Red'])
# dict_items([('Brand', 'Ford'), ('Model', 'Mustang'), ('Year', 1964), ('Colour', 'Red')])

# %%
print("Is Model present->","Model" in cars.keys())
# Out:
# Is Model present-> True

# %%
keys=['Movie','Hero','Release Year']
values=['Kantara','Rishab Shetty','2022']
movie=dict(zip(keys,values))
print(movie)
# Out:
# {'Movie': 'Kantara', 'Hero': 'Rishab Shetty', 'Release Year': '2022'}

# %%
keyl=['Movie','Hero','Release Year']
vall=['Kantara','Rishab Shetty','2022']
mdict={}
for i in range(len(keyl)):
      mdict[keyl[i]]=vall[i]
print("Movie->",mdict)
# Out:
# Movie-> {'Movie': 'Kantara', 'Hero': 'Rishab Shetty', 'Release Year': '2022'}

# %%
dict1={"Name":"John",10:[2,4,3]}
dict2=dict1
print(dict1)
print(dict2)
print()
print("After doing changes")
print()
dict1.popitem()
print(dict1)
print(dict2)
# Out:
# {'Name': 'John', 10: [2, 4, 3]}
# {'Name': 'John', 10: [2, 4, 3]}
#
# After doing changes
#
# {'Name': 'John'}
# {'Name': 'John'}

# %%
dict1={"Name":"John",10:[2,4,3]}
dict2=dict1.copy()
print(dict1)
print(dict2)
print()
print("After doing changes")
print()
dict1.popitem()
print(dict1)
print(dict2)
# Out:
# {'Name': 'John', 10: [2, 4, 3]}
# {'Name': 'John', 10: [2, 4, 3]}
#
# After doing changes
#
# {'Name': 'John'}
# {'Name': 'John', 10: [2, 4, 3]}

# %%
crops={'Rice':120,'Wheat':85,'Maize':60}
print("The number of cops cultivated by farmer-",len(crops))
# Out:
# The number of cops cultivated by farmer- 3

# %%
print("The yield of Wheat is-",crops['Wheat'])
# Out:
# The yield of Wheat is- 85

# %%
crops['Pulses']=45
print("the crops=",crops)
# Out:
# the crops= {'Rice': 120, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}

# %%
crops['Rice']=130
print("After updating the crops-",crops)
# Out:
# After updating the crops- {'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}

# %%
print("The crops grown by the famer are:",list(crops.keys()))
# Out:
# The crops grown by the famer are: ['Rice', 'Wheat', 'Maize', 'Pulses']

# %%
print("The crops yield are:",list(crops.values()))
# Out:
# The crops yield are: [130, 85, 60, 45]

# %%
print("Is sugarcane cultivated->",'Sugarcane' in crops.keys())
# Out:
# Is sugarcane cultivated-> False

# %%
crops['Wheat']=crops['Wheat']+10
print("After adding the yield of wheat->",crops)
# Out:
# After adding the yield of wheat-> {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}

# %%
print("Total yield of all crops:",sum(crops.values()))
# Out:
# Total yield of all crops: 290

# %%
for key,value in crops.items():
  print(key,"->",value)
# Out:
# Rice -> 130
# Wheat -> 55
# Maize -> 60
# Pulses -> 45

# %%
crops={'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}
crops2=crops.copy()
print(crops)
print(crops2)
# Out:
# {'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}
# {'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}

# %%
crops2.clear()
print("crops-",crops)
print("crops2",crops2)
# Out:
# crops- {'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}
# crops2 {}

# %%
{'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
print(crops["Jowar"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1991779937.py in <cell line: 0>()
#       1 {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
# ----> 2 print(crops["Jowar"])
#
# KeyError: 'Jowar'

# %%
print("Maize yield",crops['Jowar]) ,if 'Jowar' in crops, print("The yield of crop is",crops['Jowar']),else,print("No such crop")
# Out:
#   File "/tmp/ipython-input-3071246296.py", line 1
#     print("Maize yield",crops['Jowar]) ,if 'Jowar' in crops, print("The yield of crop is",crops['Jowar']),else,print("No such crop")
#                                                                                                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
crops.pop("Maize")
print(crops)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2964551109.py in <cell line: 0>()
# ----> 1 crops.pop("Maize")
#       2 print(crops)
#
# KeyError: 'Maize'

# %%
crops={'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
crops.pop("Maize")
print(crops)
# Out:
# {'Rice': 130, 'Wheat': 95, 'Pulses': 45}

# %%
crops.pop("Maize")
print(crops)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2964551109.py in <cell line: 0>()
# ----> 1 crops.pop("Maize")
#       2 print(crops)
#
# KeyError: 'Maize'

# %%
del crops["Rice"]
print(crops)
# Out:
# {'Wheat': 95, 'Pulses': 45}

# %%
T=("Pratham","Sharma",3.14,3)
print("T   -->",T)
print("Number of elements:",len(T))
print("Type of object:",type(T))
# Out:
# T   --> ('Pratham', 'Sharma', 3.14, 3)
# Number of elements: 4
# Type of object: <class 'tuple'>

# %%
T=("Pratha",)
print("T   -->",T)
print("Number of elements:",len(T))
print("Type of object:",type(T))
# Out:
# T   --> ('Pratha',)
# Number of elements: 1
# Type of object: <class 'tuple'>

# %%
T=("Pratha")
print("T   -->",T)
print("Number of elements:",len(T))
print("Type of object:",type(T))
# Out:
# T   --> Pratha
# Number of elements: 6
# Type of object: <class 'str'>

# %%
T=("Pratha")
print("T   -->",T)
print("Number of elements:",len(T))
print("Type of object:",type(T))
# Out:
# T   --> Pratha
# Number of elements: 6
# Type of object: <class 'str'>

# %%
T=("Pratham","Sharma",3.14,3)
print("T   -->",T)
i=0
print("")
while i<len(T):
  print(T[i])
  i=i+1
# Out:
# T   --> ('Pratham', 'Sharma', 3.14, 3)
#
# Pratham
# Sharma
# 3.14
# 3

# %%
T=("Pratham","Sharma",3.14,3)
print("T   -->",T)
print("")
for i in range(len(T)):
  print(T[i])
# Out:
# T   --> ('Pratham', 'Sharma', 3.14, 3)
#
# Pratham
# Sharma
# 3.14
# 3

# %%
T=("Pratham","Sharma",3.14,3)
print("T   -->",T)
for i in range(len(T)):
  print(i)
# Out:
# T   --> ('Pratham', 'Sharma', 3.14, 3)
# 0
# 1
# 2
# 3

# %%
T=("Pratham","Sharma",3.14,3)
print("T   -->",T)
print("")
for s in T:
  print(s)
# Out:
# T   --> ('Pratham', 'Sharma', 3.14, 3)
#
# Pratham
# Sharma
# 3.14
# 3

# %%
T=("Pratham","Sharma",3.14,3)
print("T   -->",T)
print("")
for a in T:
  print(a)
# Out:
# T   --> ('Pratham', 'Sharma', 3.14, 3)
#
# Pratham
# Sharma
# 3.14
# 3

# %%
T=("Pratham","Sharma",3.14,3)
print("T   -->",T)
print("")
for i in T:
  print(i)
# Out:
# T   --> ('Pratham', 'Sharma', 3.14, 3)
#
# Pratham
# Sharma
# 3.14
# 3

# %%
T=(3,6,9,12,5,3,2)
print("T    -->",T)
print("T[1]-",T[1])
print("T[2]-",T[2])
print("T[-1]-",T[-1])
print("T[-2]-",T[-2])
# Out:
# T    --> (3, 6, 9, 12, 5, 3, 2)
# T[1]- 6
# T[2]- 9
# T[-1]- 2
# T[-2]- 3

# %%
print("T[1:3]",T[1:3])
print("T[2:]",T[2:])
print("T[:4]",T[:4])
print("T[:-1]",T[:-1])
print("T[-4:-1]",T[-4:-1])
# Out:
# T[1:3] (6, 9)
# T[2:] (9, 12, 5, 3, 2)
# T[:4] (3, 6, 9, 12)
# T[:-1] (3, 6, 9, 12, 5, 3)
# T[-4:-1] (12, 5, 3)

# %%
print(T[2:5])
# Out:
# (9, 12, 5)

# %%
print(T[-2:-5])
# Out:
# ()

# %%
print("T[::1]",T[::1])
print("T[::2]",T[::2])
print("T[::-1]",T[::-1])
print("T[::-2]",T[::-2])
# Out:
# T[::1] (3, 6, 9, 12, 5, 3, 2)
# T[::2] (3, 9, 5, 2)
# T[::-1] (2, 3, 5, 12, 9, 6, 3)
# T[::-2] (2, 5, 9, 3)

# %%
T[::1]
# Out:
# (3, 6, 9, 12, 5, 3, 2)

# %%
T=("Pratham","Sharma",3.14,3)
print("T--->",T)
T[2]=9
print("T--->",T)
# Out:
# T---> ('Pratham', 'Sharma', 3.14, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-395172327.py in <cell line: 0>()
#       1 T=("Pratham","Sharma",3.14,3)
#       2 print("T--->",T)
# ----> 3 T[2]=9
#       4 print("T--->",T)
#
# TypeError: 'tuple' object does not support item assignment

# %%
T.append(9.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1748723688.py in <cell line: 0>()
# ----> 1 T.append(9.8)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
T.insert(2,"Rahul")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1675144776.py in <cell line: 0>()
# ----> 1 T.insert(2,"Rahul")
#       2
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
T.add(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3994643415.py in <cell line: 0>()
# ----> 1 T.add(6)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
del T[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1692257482.py in <cell line: 0>()
# ----> 1 del T[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
T.extend(9.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4279994569.py in <cell line: 0>()
# ----> 1 T.extend(9.8)
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
T=("Pratham","Sharma",3.14,3)
print("T--->",T)
T1=list(T)
T1.append(9.8)
T=tuple(T1)
print("")
print("After adding    ---->",T)
# Out:
# T---> ('Pratham', 'Sharma', 3.14, 3)
#
# After adding    ----> ('Pratham', 'Sharma', 3.14, 3, 9.8)

# %%
T1=list(T)
T1.insert(2,"Rahul")
T=tuple(T1)


print("After inserting    ---->",T)
# Out:
# After inserting    ----> ('Pratham', 'Sharma', 'Rahul', 'Rahul', 'Rahul', 3.14, 3, 9.8)

# %%
T1=list(T)
del T1[1]
T=tuple(T1)
print("After deleting    ---->",T)
# Out:
# After deleting    ----> ('Pratham', 'Rahul', 3.14, 3, 9.8)

# %%
T1=list(T)
print(type(T1))
del T1[1]
T=tuple(T1)
print("After deleting    ---->",T)
# Out:
# <class 'list'>
# After deleting    ----> ('Pratham', 3, 9.8)

# %%
T=(3,6,9,12,5,3,2)
print("T    -->",T)
print("Sum->",sum(T))
print("Average->",sum(T)/len(T))
print("Average->",sum(T)//len(T))
# Out:
# T    --> (3, 6, 9, 12, 5, 3, 2)
# Sum-> 40
# Average-> 5.714285714285714
# Average-> 5

# %%
print("Maximum->",max(T))
print("Minimum->",min(T))
# Out:
# Maximum-> 12
# Minimum-> 2

# %%
12 in T
# Out:
# True

# %%
9.02 in T
# Out:
# False

# %%
T1=(3,6,9)
T2=(12,5,3,2)
print("T1-->",T1)
print("T2-->",T2)
T3=T1+T2
print("T3-->",T3)
T4=T1+T2+T3
print("T4-->",T4)
# Out:
# T1--> (3, 6, 9)
# T2--> (12, 5, 3, 2)
# T3--> (3, 6, 9, 12, 5, 3, 2)
# T4--> (3, 6, 9, 12, 5, 3, 2, 3, 6, 9, 12, 5, 3, 2)

# %%
T3=T1[1:2]+T2[1:3]
print("T3-->",T3)
T4=T1[:-2]+T2[:-3]
print("T4-->",T4)
# Out:
# T3--> (6, 5, 3)
# T4--> (3, 12)

# %%
T=(3,6,9,12,5,3,2)
print("T    -->",T)
print(T.index(9))
print(T.index(3))
print(T.index(2))
print(T.index(7))
# Out:
# T    --> (3, 6, 9, 12, 5, 3, 2)
# 2
# 0
# 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-309286810.py in <cell line: 0>()
#       4 print(T.index(3))
#       5 print(T.index(2))
# ----> 6 print(T.index(7))
#
# ValueError: tuple.index(x): x not in tuple

# %%
T=(3,6,9,12,5,3,2)
print("T    -->",T)
print(T.count(9))
print(T.count(3))
print(T.count(2))
print(T.count(7))
# Out:
# T    --> (3, 6, 9, 12, 5, 3, 2)
# 1
# 2
# 1
# 0

# %%
l1=[1,2,3]
print(id(l1))
l1.append(4)
print(id(l1))
# Out:
# 132166837462208
# 132166837462208

# %%
s1={1,2,3}
print(id(s1))
s1.add(4)
print(id(s1))
# Out:
# 132166838179808
# 132166838179808

# %%
d1={'a':1,'b':2}
print(id(d1))
d1["c"]=4
print(id(d1))
# Out:
# 132166864727296
# 132166864727296

# %%
a="GKVK"
print(id(a))
a=a+'university'
print(id(a))
# Out:
# 132166849698224
# 132166853336240

# %%
s="Python"
print(id(s))
s=s+"3"
print(id(s))
print(s)
s="Python"
s[0]="J"
# Out:
# 10702304
# 132166837515824
# Python3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-510274730.py in <cell line: 0>()
#       5 print(s)
#       6 s="Python"
# ----> 7 s[0]="J"
#
# TypeError: 'str' object does not support item assignment

# %%
x=10
y=x
print(id(x))
print(id(y))
x=x+20
print(id(x))
print(id(y))
# Out:
# 11654664
# 11654664
# 11655304
# 11654664

# %%
l1=[1,2,3]
l2=l1
print(id(l1))
print(id(l2))
l1.append(4)
print(id(l1))
print(id(l2))
# Out:
# 132576854696960
# 132576854696960
# 132576854696960
# 132576854696960

# %%
print(l1)
print(l2)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]
