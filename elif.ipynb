# %%
a= int(input("Enter 1st no."))
b= int(input("Enter 2nd no."))
c=a*b
print("Product of {} and {} is {}".format(a,b,c))
# Out:
# Enter 1st no.20
# Enter 2nd no.90
# Product of 20 and 90 is 1800

# %%
for i in range(1,101,100):
  print(i)
# Out:
# 1

# %%
age=10
if(age>=18):
  print("Eligible for voting")
else:
  print("Not eligible")
# Out:
# Not eligible

# %%
a=int(input("Enter a no.= "))
if(a>0):
  print("Positive no.")
elif(a<0):
  print("Negative no.")
else:
  print("Zero")
# Out:
# Enter a no.= 96
# Positive no.
