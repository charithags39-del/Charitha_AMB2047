# %%
file=open("GKVK.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3638656465.py in <cell line: 0>()
#       1 file=open("GKVK.txt","r")
#       2 content=file.read()
# ----> 3 print(content)
#       4 file.close()
#
# TypeError: 'str' object is not callable

# %%
file=open("GKVK.txt","w")
file.write("How are you")
file.close()

# %%
file=open("GKVK.txt","a")
file.write("\nI am fine")
file.close()

# %%
file=open("GKVK.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3638656465.py in <cell line: 0>()
#       1 file=open("GKVK.txt","r")
#       2 content=file.read()
# ----> 3 print(content)
#       4 file.close()
#
# TypeError: 'str' object is not callable

# %%
file=open("ABC.txt","a")
file.write("\nI am fine")
file.close()

# %%
file=open("ABC.txt","r")
content=file.read()
print(content)
file.close()

# %%
file=open("GKVK.txt","r")
content=file.readline()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1393728809.py in <cell line: 0>()
#       1 file=open("GKVK.txt","r")
#       2 content=file.readline()
# ----> 3 print(content)
#       4 file.close()
#
# TypeError: 'str' object is not callable

# %%
file=open("GKVK.txt","r")
content=file.readlines()
print(content)
file.close()

# %%
with open("GKVK.txt","r") as file:
    print(file.read())

# %%
try:
    file=open("xyz","r")
    content=file.read()
    print(content)
except:
    print("File not found")

# %%
try:
    file=open("xyz","r")
    content=file.read()
    print(content)
except:
    print("File not found")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1400791709.py in <cell line: 0>()
#       1 try:
# ----> 2     file=open("xyz","r")
#       3     content=file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xyz'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1400791709.py in <cell line: 0>()
#       4     print(content)
#       5 except:
# ----> 6     print("File not found")
#
# TypeError: 'str' object is not callable

# %%
try:
    a=10
    b=20
    c=a+b  # Changed 'd' to 'b'
    print(c)
except:
    print("Something went wrong")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1890887892.py in <cell line: 0>()
#       3     b=20
# ----> 4     c=a+d
#       5     print(c)
#
# NameError: name 'd' is not defined
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1890887892.py in <cell line: 0>()
#       5     print(c)
#       6 except:
# ----> 7     print("Something went wrong")
#
# TypeError: 'str' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3920825395.py in <cell line: 0>()
#       4 a=5
#       5 b=4
# ----> 6 c=expr(a,b)
#       7 print(c)
#
# /tmp/ipython-input-3920825395.py in expr(a, b)
#       1 def expr(a,b):
#       2     c=a/b
# ----> 3     print(c)
#       4 a=5
#       5 b=4
#
# TypeError: 'str' object is not callable
