# %%
file=open("abc.txt","r")
content=file.read()
print(content)             # if content doesn't exits in a file it throws an error
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2749428419.py in <cell line: 0>()
# ----> 1 file=open("abc.txt","r")
#       2 content=file.read()
#       3 print(content)
#       4 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
file=open("GKVK.txt","w")
file.write("Hello world")
file.close()          # open folder you will get a file created using write as it is in write mode u will not get an output
                           #instead folder will be created

# %%
file=open("GKVK.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# How r u
# This is appended textThis is appended text
# This is appended text

# %%
file=open("GKVK.txt","w")
file.write("How r u")            #old content is deleted
file.close()                           #file is created if it doesn't exists

# %%
file=open("GKVK.txt","a")
file.write("\nThis is appended text")   #old content is not deleted
file.close()                                #New data goes to the end of thefile
                                                  #file is created if it doesn't exists

# %%
file=open("UASB.txt","a")
file.write("\nThis is appended text")      #file is created as it doesn't existed
file.close()

# %%
file=open("GKVK.txt","r")
content=file.readline()
print(content)
file.close()                 #reads only the 1st line
# Out:
# How r u

# %%
file=open("GKVK.txt","r")
content=file.readlines()
print(content)
file.close()                      # complete contnt is given in the form of list
# Out:
# ['How r u\n', 'This is appended textThis is appended text\n', 'This is appended text']

# %%
with open("GKVK.txt","r") as file:
  print(file.read())
# Out:
# Nanditha is a good girlRakshitha is also good as Nanditha/n Rakshitha is also good as Nanditha

# %%
with open("GKVK.txt","w") as file:
  (file.write("Nanditha is a good girl"))

# %%
with open("GKVK.txt","a") as file:
 (file.write())

# %%
#exception handling with files
try:
  file=open("xyz.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("no such files")
# Out:
# no such files

# %%
#exception handling with files
try:
  file=open("GKVK.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("no such files")
# Out:
# Nanditha is a good girlRakshitha is also good as Nanditha/n Rakshitha is also good as Nanditha

# %%
try:
  with open("abc,txt","r") as f:
    line=f.read()
    print(line)
except:
  print("errror!! no such file")
# Out:
# errror!! no such file

# %%
try:
  a=10
  b=20
  c=a+d
  print(c)
except:
  print("some issue")
# Out:
# some issue

# %%
# write a program to do the dividion using function
def expr(a=10,b=0):
  c=a/b
  print(c)

expr()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-1397892373.py in <cell line: 0>()
#       4   print(c)
#       5
# ----> 6 expr()
#
# /tmp/ipython-input-1397892373.py in expr(a, b)
#       1 # write a program to do the dividion using function
#       2 def expr(a=10,b=0):
# ----> 3   c=a/b
#       4   print(c)
#       5
#
# ZeroDivisionError: division by zero

# %%
def expr(a,b):
  try:
     c=a/f  #a/b
  except ZeroDivisionError:
    print("divided by zero")
  except NameError:
    print("variable not declared")
  else:
    print("ececuted without errors")
    print("value of c",c)
  finally:print("end of the programme")
a=5
b=2
expr(a,b)
# Out:
# variable not declared
# end of the programme
