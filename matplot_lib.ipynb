# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#4. Numerical Example
#Suppose we want to predict whether a person will buy a computer based on Age and Income.
Training Dataset:
Age     Income Buy    Computer
Young      High          No
Young      High          No
Middle     High          Yes
Old        Medium        Yes
Old        Low           Yes
Old        Low           No
Middle     Low           Yes
Young      Medium        No
Young      Low           Yes
Old        Medium        Yes

New Data
Age =Young
Income = Medium
