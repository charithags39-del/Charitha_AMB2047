# %%
# ex2
print("t[1:3] ",t[1:3])
print("t[2: ] ",t[2: ])
print("t[2:5] ",t[2:5])
print("t[ :2] ",t[ :2])
print("t[ :-1] ",t[ :-1])
print("t[-4:-1] ",t[-4:-1])
# Out:
# t[1:3]  (6, 9)
# t[2: ]  (9, 12, 5, 3, 2)
# t[2:5]  (9, 12, 5)
# t[ :2]  (3, 6)
# t[ :-1]  (3, 6, 9, 12, 5, 3)
# t[-4:-1]  (12, 5, 3)

# %%
t=(3,6,9,12,5,3,2)

# %%
#method 1
t=("nanditha","rakshitha",49.0,206)
print("t  ",t)
print("number of elements  ",len(t))
print("type of object  ", type(t))
# Out:
# t   ('nanditha', 'rakshitha', 49.0, 206)
# number of elements   4
# type of object   <class 'tuple'>

# %%
#method 2
t=tuple(["nanditha","rakshitha",49.0,206])   #conversion of list to tuple
print("t  ",t)
print("number of elements  ",len(t))
print("type of object  ", type(t))
# Out:
# t   ('nanditha', 'rakshitha', 49.0, 206)
# number of elements   4
# type of object   <class 'tuple'>

# %%
# tuple with one item
t=("pritviraj",)
print("t  ",t)
print("number of elements  ",len(t))
print("type of object  ", type(t))
# Out:
# t   ('pritviraj',)
# number of elements   1
# type of object   <class 'tuple'>

# %%
#not a tuple it is a string
t=("prithviraj")
print("t  ",t)
print("number of elements  ",len(t))
print("type of object  ", type(t))
# Out:
# t   prithviraj
# number of elements   10
# type of object   <class 'str'>

# %%
#tuple iteration using while loop
t=tuple(["nanditha","rakshitha",49.0,206])
i=0
print("")
while i < len(t):
  print(t[i])
  i+=1
# Out:
# nanditha
# rakshitha
# 49.0
# 206

# %%
t=tuple(["nanditha","rakshitha",49.0,206])
print("t  ",t)
print("")
for i in range(len(t)):
  print(t[i])
# Out:
# t   ('nanditha', 'rakshitha', 49.0, 206)
#
# nanditha
# rakshitha
# 49.0
# 206

# %%
t=tuple(["nanditha","rakshitha",49.0,206])
print("t  ",t)
print("")
for i in t:
  print(i)
# Out:
# t   ('nanditha', 'rakshitha', 49.0, 206)
#
# nanditha
# rakshitha
# 49.0
# 206

# %%
# accsessing 1st element
t=(3,6,9,12,5,3,2)
print(" t  ",t)
# Out:
#  t   (3, 6, 9, 12, 5, 3, 2)

# %%
print(t[4])
# Out:
# 5

# %%
# ex2
print("t[1:3] ",t[1:3])
print("t[2: ] ",t[2: ])
print("t[2:5] ",t[2:5])
print("t[ :2] ",t[ :2])
print("t[ :-1] ",t[ :-1])
print("t[-4:-1] ",t[-4:-1])
print("t[1:-1]" ,t[1:-1])
print("t[-1::-4]" ,t[-1::-4])
# Out:
# t[1:3]  (6, 9)
# t[2: ]  (9, 12, 5, 3, 2)
# t[2:5]  (9, 12, 5)
# t[ :2]  (3, 6)
# t[ :-1]  (3, 6, 9, 12, 5, 3)
# t[-4:-1]  (12, 5, 3)
# t[1:-1] (6, 9, 12, 5, 3)
# t[-1::-4] (2, 9)

# %%
t=(3,6,9,12,5,3,2)
print("t  ",t[ ::1])
# Out:
# t   (3, 6, 9, 12, 5, 3, 2)

# %%
print("t  ",t[ ::-1]) # reverse
# Out:
# t   (2, 3, 5, 12, 9, 6, 3)

# %%
print("t  ",t[ ::2]) # alternate numbers
# Out:
# t   (3, 9, 5, 2)

# %%
print("t  ",t[ ::-2])
# Out:
# t   (2, 5, 9, 3)

# %%
t=(3,6,9,12,5,3,2,"rakshith")
t[2]=900
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2748700504.py in <cell line: 0>()
#       1 t=(3,6,9,12,5,3,2,"rakshith")
# ----> 2 t[2]=900
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.append(9,8)
print(t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1644661032.py in <cell line: 0>()
# ----> 1 t.append(9,8)
#       2 print(t)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.insert(2,"rahul")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3701532389.py in <cell line: 0>()
# ----> 1 t.insert(2,"rahul")
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
t.add(49)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2730711112.py in <cell line: 0>()
# ----> 1 t.add(49)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
del t[68]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-88814309.py in <cell line: 0>()
# ----> 1 del t[68]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
T=("NANDITHA V","MOHAN ROA")
T1=list(T)
T1.insert(1,"PRITHVI RAJ")
T=tuple(T1)
print(T)
# Out:
# ('NANDITHA V', 'PRITHVI RAJ', 'MOHAN ROA')

# %%
T=("NANDITHA V","MOHAN ROA")
T1=list(T)
T1.append("PRITHVI RAJ")
T=tuple(T1)
print(T)
# Out:
# ('NANDITHA V', 'MOHAN ROA', 'PRITHVI RAJ')

# %%
T=('NANDITHA V', 'MOHAN ROA', 'PRITHVI RAJ')
T1=list(T)
T1.pop(1)
T=tuple(T1)
print(T)
# Out:
# ('NANDITHA V', 'PRITHVI RAJ')

# %%
t=(3,6,9,12,5,3,2)
print("T ", max(t))
# Out:
# T  12

# %%
print("T ", min(t))
# Out:
# T  2

# %%
print(" 6 in T", 6 in t)
# Out:
#  6 in T True

# %%
print("49 in t ", 49 in t)
# Out:
# 49 in t  False

# %%
t1=(1,2,3)
t2=(4,5,6,3)
t3=t1+t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6, 3)

# %%
t4=t1+t2+t1+t2
print(t4)
# Out:
# (1, 2, 3, 4, 5, 6, 3, 1, 2, 3, 4, 5, 6, 3)

# %%
t1=(1,2,3)
t2=(4,5,6,3)

t3=t1[1:2]+t2[1:3]
print(t3)

t4=t1[:-2]+t2[:-3]
print(t4)
# Out:
# (2, 5, 6)
# (1, 4)

# %%
t=(3,6,9,12,5,3,2)
print("index of 9 in t", t.index(9))
# Out:
# index of 9 in t 2

# %%
print("index of 49 in t", t.index(49))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-92654656.py in <cell line: 0>()
# ----> 1 print("index of 49 in t", t.index(49))
#
# ValueError: tuple.index(x): x not in tuple

# %%
print("index of  in t", t.index(3))
# Out:
# index of  in t 0

# %%
print(" count of 3 is ", t.count(3))
print(" count of 5is ", t.count(5))
# Out:
#  count of 3 is  2
#  count of 5is  1

# %%
l1=[1,2,3]
print(id(l1))
l1.append(4)
print(id(l1))
# Out:
# 136242238688640
# 136242238688640

# %%
s1={1,2,3}
print(id(s1))
s1.add(4)
print(id(s1))
# Out:
# 136242236304384
# 136242236304384

# %%
d={1:2,2:3,3:4}
print(id(d))
d.pop(1)
print(id(d))
print (d)
# Out:
# 136242238665664
# 136242238665664
# {2: 3, 3: 4}

# %%
a="GKVK"
print(id(a))
a =a+"university"
print(id(a))
print(a)
# Out:
# 136242243041056
# 136242237695600
# GKVKuniversity

# %%
s="python"
print(id(a))
s=s+"3"
print(id(s))
print(s)
# Out:
# 136242237695600
# 136242248029392
# python3

# %%
s="python"
s[0]="j"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2144580629.py in <cell line: 0>()
#       1 s="python"
# ----> 2 s[0]="j"
#
# TypeError: 'str' object does not support item assignment

# %%
x=10
y=x
print(id(x))
print(id(y))

x=x+20
print(id(x))
print(id(y))
# Out:
# 11654664
# 11654664
# 11655304
# 11654664

# %%
+
