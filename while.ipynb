# %% [markdown]
# # Welcome to Colab!

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(1))
# Out:
# True

# %%
print(bool("hello"))
# Out:
# True

# %%
for i in range(1,11):
  if i==6:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 10

# %%
i=1
while(i<=10):
  if(i==6):
    i+=1
    continue
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 10

# %%
i=1
while(i<=10):
  if i==4 or i==6:
    i+=1
    continue
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 5
# 7
# 8
# 9
# 10

# %%
for i in range(1,11):
  if i==4 or i==6:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 5
# 7
# 8
# 9
# 10

# %%
i=1
while(i<=20):
  if i%3==0:
    print(i)
  i+=1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18

# %%
i=1
while(i<=10):
  if i==6:
    break
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num=1
while num!=0:
  num=int(input("Enter number"))
  print(num)
# Out:
# Enter number2
# 2
# Enter number2
# 2
# Enter number4
# 4
# Enter number0
# 0

# %%
num=1
while num!=0:
  num=int(input("Enter number"))
print(num)
# Out:
# Enter number9
# Enter number0
# 0

# %%
password=""

while password!="python":
  password=input("Enter password")
print("Access granted")
# Out:
# Enter passwordcharitha
# Enter passwordpython
# Access granted

# %%
n=1

while sum<=15:
  sum+=n
  n+=1
print(sum)
# Out:
# 136

# %%
n=1
sum+=n
while sum<=15:
  n+=1
print(sum)
# Out:
# 138

# %%
n=1
sum+=n
while sum<=15:
  n+=1
print(sum)
# Out:
# 139

# %%
n=1
sum=0
while sum<=15:
  n+=1
  sum+=n
  if sum==15:
    break

print(n)
print(sum)
# Out:
# 6
# 20

# %%
n=1
sum=0
while (n<=5):
  sum+=n
  n+=1
print(sum)
# Out:
# 15

# %%
sum=0
for i in range(1,6):
  sum=sum+i
print(sum)
# Out:
# 15

# %%
sum=15

for i in range(1,i):
  sum=sum+i
  print(i)

# %%
n=1
sum=50
while(sum<=50):
  sum=sum+n
  n+=1
  print(sum)
# Out:
# 51

# %%
n=1
sum=0
while(sum<=50):
  sum=sum+n
  n+=1
print(sum)
print(n-1)
# Out:
# 55
# 10

# %%
s=0
for s in range(1,51):
  s=s+i
print(s)
# Out:
# 51

# %%
S={'A','F','Y','M','U','R'}
print("S   ->",S)
# Out:
# S   -> {'F', 'U', 'R', 'M', 'A', 'Y'}

# %%
A={'D','S','D','D','S','G','F','D'}

# %%
print("The number of elements->",len(A))
# Out:
# The number of elements-> 4

# %%
print("A->",A)
# Out:
# A-> {'F', 'G', 'S', 'D'}

# %%
print("The number of elements->",len(S))
# Out:
# The number of elements-> 6

# %%
print("the type of object->",type(S))
# Out:
# the type of object-> <class 'set'>

# %%
print("")
for i in S:
  print(i)
# Out:
# F
# U
# R
# M
# A
# Y

# %%
print(S[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3458961075.py in <cell line: 0>()
# ----> 1 print(S[2])
#
# TypeError: 'set' object is not subscriptable

# %%
S.add("D")
print("after adding D",S)
# Out:
# after adding D {'F', 'D', 'U', 'R', 'M', 'A', 'Y'}

# %%
S.add("D")
print("after adding D",S)
# Out:
# after adding D {'F', 'D', 'U', 'R', 'M', 'A', 'Y'}

# %%
S.add("C")
print("after adding C",S)
# Out:
# after adding C {'C', 'F', 'D', 'U', 'R', 'M', 'A', 'Y'}

# %%
S.add("A")
print("after adding A",S)
# Out:
# after adding A {'C', 'F', 'D', 'U', 'R', 'M', 'A', 'Y'}

# %%
s1={"A","B","C"}
s2={"D","E","F"}
print("S1->",s1)
print("S2->",s2)
s1.update(s2)
print("updated S1->",s1)
print("updated S2->",s2)
# Out:
# S1-> {'C', 'B', 'A'}
# S2-> {'F', 'D', 'E'}
# updated S1-> {'C', 'F', 'D', 'B', 'A', 'E'}
# updated S2-> {'F', 'D', 'E'}

# %%
S={"A","B","C","D"}
print("S->",S)
S.remove("D")
print("S->",S)
# Out:
# S-> {'C', 'B', 'A', 'D'}
# S-> {'C', 'B', 'A'}

# %%
S={'A','B','C','D'}
print("S->",S)
S.discard("D")
print("S->",S)
# Out:
# S-> {'C', 'B', 'A', 'D'}
# S-> {'C', 'B', 'A'}

# %%
S={'A','B','C','D'}
print("S->",S)
S.update('K','J','M','A')
print("updated set",S)
# Out:
# S-> {'C', 'B', 'A', 'D'}
# updated set {'C', 'K', 'A', 'J', 'D', 'B', 'M'}

# %%
S={'A','B','C','D'}
print("S->",S)
S.pop()
print("S->",S)
# Out:
# S-> {'C', 'B', 'A', 'D'}
# S-> {'B', 'A', 'D'}

# %%
S={'A','B','C','D'}
print("S->",S)
S.pop(C)
print("S->",S)
# Out:
# S-> {'C', 'B', 'A', 'D'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4022659584.py in <cell line: 0>()
#       1 S={'A','B','C','D'}
#       2 print("S->",S)
# ----> 3 S.pop(C)
#       4 print("S->",S)
#
# NameError: name 'C' is not defined

# %%
S.clear()
print("S->",S)
# Out:
# S-> set()

# %%
S={"A","B","C","D"}
print("S->",S)
S.remove("D")
print("S->",S)
# Out:
# S-> {'C', 'B', 'A', 'D'}
# S-> {'C', 'B', 'A'}

# %%
S.remove("D")
print("S->",S)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2049312799.py in <cell line: 0>()
# ----> 1 S.remove("D")
#       2 print("S->",S)
#       3
#
# KeyError: 'D'

# %%
S={'A','B','C','D'}
print("S->",S)
S.discard("D")
print("S->",S)
# Out:
# S-> {'C', 'B', 'A', 'D'}
# S-> {'C', 'B', 'A'}

# %%
S.discard("D")
print("S->",S)
# Out:
# S-> {'C', 'B', 'A'}

# %%
S.clear()
print("S->",S)
# Out:
# S-> set()

# %%
S.pop()
print("S->",S)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4113777005.py in <cell line: 0>()
# ----> 1 S.pop()
#       2 print("S->",S)
#
# KeyError: 'pop from an empty set'

# %%
del S
print("S->",S)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1150588964.py in <cell line: 0>()
#       1 del S
# ----> 2 print("S->",S)
#
# NameError: name 'S' is not defined

# %%
S={1,2,3,4,5}
print("S:",S)
print("sum-",sum(S))
print("max-",max(S))
print("min-",min(S))
print("aveage",sum(S)/len(S))
# Out:
# S: {1, 2, 3, 4, 5}
# sum- 15
# max- 5
# min- 1
# aveage 3.0

# %%
S={1,3,5,6,8,9}
print("S->",S)
print("Is 2 present",2 in S)
print("Is 9 present",9 in S)
# Out:
# S-> {1, 3, 5, 6, 8, 9}
# Is 2 present False
# Is 9 present True

# %%
a=set(['A','B','E','F'])
b=set(["A","B","C","D","E"])
print("Set a",a)
print("Set b",b)
# Out:
# Set a {'F', 'B', 'A', 'E'}
# Set b {'C', 'A', 'E', 'D', 'B'}

# %%
print("Union of a and b",a.union(b))
print("Intersection of a and b",a.intersection(b))
print("Difference of a and b",a.difference(b))
print("Difference of a and b",(a-b))
print("Difference of b and a",b.difference(a))
print("Difference of b and a",(b-a))
print("Symmetric difference of a and b:",a.symmetric_difference(b))
print("Symmetric difference of b and a:",b.symmetric_difference(a))
# Out:
# Union of a and b {'C', 'A', 'E', 'F', 'D', 'B'}
# Intersection of a and b {'B', 'A', 'E'}
# Difference of a and b {'F'}
# Difference of a and b {'F'}
# Difference of b and a {'C', 'D'}
# Difference of b and a {'C', 'D'}
# Symmetric difference of a and b: {'C', 'F', 'D'}
# Symmetric difference of b and a: {'C', 'F', 'D'}

# %%
S={'a','b','c','d'}
print("S->",S)
S.add('e')
print("S->",S)
# Out:
# S-> {'a', 'd', 'b', 'c'}
# S-> {'a', 'd', 'c', 'b', 'e'}

# %%
S=set(['a','b','c','d'])
print("s->",S)
# Out:
# s-> {'a', 'd', 'b', 'c'}

# %%
S.update('e')
print(S)
# Out:
# {'a', 'd', 'c', 'b', 'e'}

# %%
S=set(['a','b','c','d'])
S.discard('f')
print(S)
# Out:
# {'b', 'd', 'c', 'a'}

# %%
S=set(['a','b','c','d'])
S.remove('f')
print(S)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3779184551.py in <cell line: 0>()
#       1 S=set(['a','b','c','d'])
# ----> 2 S.remove('f')
#       3 print(S)
#
# KeyError: 'f'

# %%
S.pop()

print(S)
# Out:
# {'d', 'c', 'a'}

# %%
S.pop()
print(S)
# Out:
# {'c', 'a'}

# %%
S.pop()
print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2103124762.py in <cell line: 0>()
# ----> 1 S.pop()
#       2 print()
#
# KeyError: 'pop from an empty set'

# %%
[print(x) for x in ['apple', 'banana', 'cherry']]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
print(x) for x in ['apple', 'banana', 'cherry']:
# Out:
#   File "/tmp/ipykernel_4359/621403189.py", line 1
#     print(x) for x in ['apple', 'banana', 'cherry']:
#              ^
# SyntaxError: invalid syntax

# %%
for x in ['apple', 'banana', 'cherry']:
   print(x)
# Out:
# apple
# banana
# cherry
